# %%
print("Bienvenido")
# Out:
# Bienvenido

# %% [markdown]
# Tipos de datos:
# - boolean: true, false
# - int:5, -7, 0
# - float: 3.1416, -3.7
# - char: "t", "5", "%"
# Tipos de datos (compuestos)
# - string: "t", "5", "%", "angel"
# -Tupla: ("Yaqueline", "Luis Enrique", "Perla", "Uriel") (constante)
# -Listas: (),["Yaqueline","Luis Enrique", "Perla", "Uriel"] (variable)
# - Diccionario ("elemento1":cuaderno,"elemento2" :lapiz)

# %% [markdown]
# Python debilmente tipado

# %%
nombre ="Angel"
edad = 29
print("Bienvenido " + nombre)
# Out:
# Bienvenido Angel

# %%
hermanas = 2; #int Perla
print("Yo tengo",hermanas,"hermanas.")

estatura = 1.53 #float
print("Mi estatura es de",estatura,"m.")

esMayor = True #boolean
print("¿La persona es mayor de edad?",esMayor)

domicilio = "Av. Ing. Militares y Av. Mexico Tacuba" #string
print("La UTC Toreo se encuentra en",domicilio)
# Out:
# Yo tengo 2 hermanas.
# Mi estatura es de 1.53 m.
# ¿La persona es mayor de edad? True
# La UTC Toreo se encuentra en Av. Ing. Militares y Av. Mexico Tacuba

# %%
respuestaUsuario = input("¿Como estas?")
print("La respuesta del usuario es: ", respuestaUsuario)
# Out:
# ¿Como estas?nv
# La respuesta del usuario es:  nv

# %%
respuestaUsuario = input("¿Cual es tu edad?")
print(type(respuestaUsuario))
respuestaUsuario = int(respuestaUsuario)
print("La respuesta del ususario es:", respuestaUsuario)
print(type(respuestaUsuario))
# Out:
# ¿Cual es tu edad?3
# <class 'str'>
# La respuesta del ususario es: 3
# <class 'int'>

# %%
print(31/3) #10.33333
print(31//3) #10 #cerrado
print(31%3) #1 #resuduo

# %% [markdown]
# NOT

# %%
print(not False)
print(not True)

# %% [markdown]
# Or

# %%
print(False or False)
print(False or True)
print(True or False)
print(True or True)

# %% [markdown]
# And

# %%
print(False and False)
print(False and True)
print(True and False)
print(True and True)

# %%
print(15>=18) #false
print(25>=18) #true
print(18>18) #false

# %% [markdown]
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética:
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
resultado = ((3 + 2) / (2 * 5)) ** 2

print("El resultado es:", resultado)

# %%
dividendo = int(input("Ingresa el dividendo: "))
divisor = int(input("Ingresa el divisor:"))
cociente = dividendo // divisor
residuo = dividendo % divisor
print(f"{dividendo} entre {divisor} da un cociente {cociente} y un residuo {residuo}")

# %%
edad = 80
if edad > 17 and edad < 60:
  print("Puede pasar")
elif edad > 59:
  print("Puede pasar y tiene descuento ")
else:
  print(" No puede pasar")

# %% [markdown]
# La pizzería Bella Napoli ofrece pizzas vegetarianas y no vegetarianas a sus clientes. Los ingredientes para cada tipo de pizza aparecen a continuación.
#
# 1.Ingredientes vegetarianos: a.Pimiento b.Tofu
#
# 2.Ingredientes no vegetarianos: a.Peperoni b.Jamón c.Salmón.
#
# Escribir un programa donde se tengan 2 variables una para especificar el tipo de pizza y otra para el ingrediente (utiliza la letra y el número especificado arriba para definir las opciones). Solo se puede eligir un ingrediente además de la mozzarella y el tomate que están en todas la pizzas. Al final se debe mostrar por pantalla si la pizza elegida es vegetariana o no y todos los ingredientes que lleva.

# %%
eleccionTipoPizza = input("Bienvenido. Escoge una opcion:Vegetariana (v) No vegetariana (nv)")
if eleccionTipoPizza == "v":
  eleccionIngrediente = input("Escoge una opcion: Pimiento (p) Tofu (t)")
  if eleccionIngrediente == "p":
    print("Escogiste una pizza vegetariana con pimiento, mozzarella y tomate ")
  elif eleccionIngrediente == "t":
    print("Escogiste una pizza vegetariana con Tofu, mozzarella y tomate.")
elif eleccionTipoPizza =="nv":
  eleccionIngredientes = input ("Escoge una opcion: Peperoni (p) Jamon (j) Salmon (s)")
  if eleccionIngrediente == "p":
        print("Escogiste una pizza no vegetariana con Peperoni, mozzarella y tomate.")
  elif eleccionIngrediente == "j":
        print("Escogiste una pizza no vegetariana con Jamón, mozzarella y tomate.")
  elif eleccionIngrediente == "s":
        print("Escogiste una pizza no vegetariana con Salmón, mozzarella y tomate.")
# Out:
# Bienvenido. Escoge una opcion:Vegetariana (v) No vegetariana (nv)nv
# Escoge una opcion: Peperoni (p) Jamon (j) Salmon (s)s

# %%
eleccionTipoPizza = "0"
while eleccionTipoPizza != "s":
  eleccionTipoPizza = input ("Bienvenido. Escoge una opcion: Vegetariana (v) No vegetariana (nv) salir (s) ")
  print("Bloque repetido")

# %%
numero = int(input("ingresa un numero"))
for i in range(1,11):
  resultado = numero * i
  print(f"{numero} x {i} es igual a {resultado}")
# Out:
# ingresa un numero4
# 4 x 1 es igual a 4
# 4 x 2 es igual a 8
# 4 x 3 es igual a 12
# 4 x 4 es igual a 16
# 4 x 5 es igual a 20
# 4 x 6 es igual a 24
# 4 x 7 es igual a 28
# 4 x 8 es igual a 32
# 4 x 9 es igual a 36
# 4 x 10 es igual a 40

# %% [markdown]
# Escribir un programa que almacene la cadena de caracteres contraseña en una variable, pregunte al usuario por la contraseña hasta que introduzca la contraseña correcta

# %%
contraseña = "I123Y"
while True:
  usuario = input("Ingresar contraseña: ")
  if usuario == contraseña:
    print("Contraseña correcta")
    break
  else:
      print("Contraseña incorrecta, intenta de nuevo")

# %% [markdown]
# ESCRIBIR UN PROGRAMA QUE PIDA AL USUSARIO UNA PALABRA Y LA MUESTRE 10 VECES

# %%
palabra = input("Escribe una palabra: ")

for i in range(10):
    print(palabra)
# Out:
# Escribe una palabra: BALON
# BALON
# BALON
# BALON
# BALON
# BALON
# BALON
# BALON
# BALON
# BALON
# BALON

# %% [markdown]
# Escribir un programa que muestre por consola (con un print) los numeros de 1 al 100 (ambos incluidos y con un salto de linea entre cada impresion), sustituyendo los siguientes:
# -Multiplos de 3 por la palabra "fizz"
# -Multiplos de 5 por la palabra "buzz"
# -Multiplos de 3 y 5 a la vez por la palabra "fizzbuzz"

# %%
for numero in range(1, 101):

    if numero % 3 == 0 and numero % 5 == 0:
        print("fizzbuzz")

    elif numero % 3 == 0:
        print("fizz")

    elif numero % 5 == 0:
        print("buzz")

    else:
        print(numero)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# buzz

# %% [markdown]
# Escribir un programa que pida al ususario un numero entero y muestre en pantalla si es un numero primo o no

# %%
numero = int(input("Ingresa un número entero: "))

if numero > 1:
    es_primo = True

    for i in range(2, numero):
        if numero % i == 0:
            es_primo = False
            break

    if es_primo:
        print("El número es primo")
    else:
        print("El número no es primo")

else:
    print("El número no es primo")
# Out:
# Ingresa un número entero: 89
# El número es primo

# %% [markdown]
# LISTA

# %%
#Creacion lista
alumnos = ["Jose","Perla"]
estudiantes =[]
estudiantes = alumnos.copy()
print(alumnos, "alumnos")
print(estudiantes,"estudiantes")
estudiantes.pop() #elimina el ultimo elemento
print(estudiantes,"estudiantes")
print(alumnos,"alumnos")
estudiantes.append("Angel")
print(estudiantes, "estudiantes")
print(alumnos.count("Jose"))
print(len(alumnos))
# Out:
# ['Jose', 'Perla'] alumnos
# ['Jose', 'Perla'] estudiantes
# ['Jose'] estudiantes
# ['Jose', 'Perla'] alumnos
# ['Jose', 'Angel'] estudiantes
# 1
# 2

# %% [markdown]
# TUPLA

# %%
tupla = (1,4.5, True, "Hola", [1,2,3])
print(tupla)
#tupla.append ("a")
print(tupla[3])
for i in tupla:
  print(i)
# Out:
# (1, 4.5, True, 'Hola', [1, 2, 3])
# Hola
# 1
# 4.5
# True
# Hola
# [1, 2, 3]

# %% [markdown]
# SUMAR LOS ELEMENTOS DE UNA LISTA

# %%
numeros = [10, 20, 30, 40, 50]
suma = sum(numeros)
print("La suma es:", suma)
# Out:
# La suma es: 150

# %%
from collections import Counter
frutas = ["manzana", "pera", "manzana", "uva", "manzana"]
conteo = Counter(frutas)
print("Resultado del conteo:")
for elemento, cantidad in conteo.items():
    print(f"{elemento}: {cantidad}")
# Out:
# Resultado del conteo:
# manzana: 3
# pera: 1
# uva: 1

# %%
numeros = [1, 2, 3, 4, 5]
numeros_invertidos = numeros[::-1]
print("Lista original:", numeros)
print("Lista invertida:", numeros_invertidos)
saludo()
# Out:
# Lista original: [1, 2, 3, 4, 5]
# Lista invertida: [5, 4, 3, 2, 1]
# ¡Hola amigo!

# %%
#ESCRIBIR UNA FUNCION QUE MUESTRE POR PANTALLA EL SALUDO !HOLA AMIGO! CADA VEZ QUE SE LA INVOQUE.
def saludo():
    print("¡Hola amigo!")
saludo()
# Out:
# ¡Hola amigo!

# %%
saludo()
# Out:
# ¡Hola amigo!

# %%
#ESCRIBIR UNA FUNCION A LA QUE SE LE PASE UNA CADENA <NOMBRE> Y MUESTRE POR PANTALLA EL SALUDO !HOLA <NOMBRE>!.
def saludo(nombre):
    print("¡Hola", nombre + "!")
nombre = input("Ingresa tu nombre: ")
saludo(nombre)
# Out:
# Ingresa tu nombre: yaqui
# ¡Hola yaqui!

# %%
#Escribir una función que reciba un número entero positivo y devuelva su factorial.
def factorial(n):
    resultado = 1
    for i in range(1, n + 1):
        resultado *= i
    return resultado
numero = int(input("Ingresa un número entero positivo: "))
print("El factorial es:", factorial(numero))
# Out:
# Ingresa un número entero positivo: 8
# El factorial es: 40320

# %%
#FACTURAS IVA
def total_factura(cantidad, iva=21):
    total = cantidad + (cantidad * iva / 100)
    return total
cantidad = float(input("Ingresa la cantidad sin IVA: "))
print("Total con IVA:", total_factura(cantidad))
# Out:
# Ingresa la cantidad sin IVA: 345
# Total con IVA: 417.45

# %%
#AREA DE UN CIRCULO
# Función para calcular el área del círculo
def area_circulo(radio): # pi * r**2
    return 3.14 * radio * radio
def volumen_cilindro(radio, altura): #V=pi r**2 *h
    return area_circulo(radio) * altura
r = float(input("Ingresa el radio: "))
h = float(input("Ingresa la altura: "))
print("Área del círculo:", area_circulo(r))
print("Volumen del cilindro:", volumen_cilindro(r, h))
# Out:
# Ingresa el radio: 8
# Ingresa la altura: 8
# Área del círculo: 200.96
# Volumen del cilindro: 1607.68

# %%
diccionario = {
    "Angel":8,
    "Juan":10,
    "Pedro":5
}
#diccionario["Pedro"]
diccionario.get("Angel")
diccionario.items()
diccionario.keys()

for nombre in diccionario:
  print(nombre)
# Out:
# Angel
# Juan
# Pedro

# %%
import csv

with open("ventas.csv" , "r") as archivo:
  lector = csv.reader(archivo)
  for fila in lector:
    print(fila)
# Out:
# ['ID_Venta', 'Fecha', 'Producto', 'Categoria', 'Cantidad', 'Precio_Unitario', 'Ciudad', 'Vendedor']
# ['1', '2026-01-05', 'Laptop HP', 'Laptops', '2', '14500', 'CDMX', 'Ana']
# ['2', '2026-01-05', 'Mouse Logitech', 'Accesorios', '5', '350', 'CDMX', 'Carlos']
# ['3', '2026-01-06', 'Monitor Samsung', 'Monitores', '1', '4200', 'Puebla', 'Ana']
# ['4', '2026-01-06', 'Teclado Redragon', 'Accesorios', '3', '850', 'Toluca', 'Luis']
# ['5', '2026-01-07', 'Laptop Lenovo', 'Laptops', '1', '16500', 'Puebla', 'Carlos']
# ['6', '2026-01-08', 'SSD Kingston', 'Almacenamiento', '4', '1200', 'CDMX', 'Ana']
# ['7', '2026-01-08', 'Memoria RAM 16GB', 'Componentes', '3', '1800', 'Toluca', 'Luis']
# ['8', '2026-01-09', 'Monitor LG', 'Monitores', '2', '3900', 'Puebla', 'Carlos']
# ['9', '2026-01-10', 'Laptop ASUS', 'Laptops', '1', '17500', 'CDMX', 'Ana']
# ['10', '2026-01-10', 'Mouse Logitech', 'Accesorios', '6', '350', 'Toluca', 'Luis']
# ...

# %%
import csv

total = 0
with open("ventas.csv" , "r") as archivo:
  lector = csv.DictReader(archivo)

  for fila in lector:
    #print(fila)
    cantidad = int(fila["Cantidad"])
    precio = float(fila["Precio_Unitario"])
    total += cantidad * precio
print("Ventas totales:", total)
# Out:
# Ventas totales: 170300.0

# %%
import csv
with open("calificaciones.csv" , "r") as archivo:
  lector = csv.reader(archivo)
  for fila in lector:
    print(fila)
# Out:
# ['Matricula', 'Nombre', 'Carrera', 'Parcial1', 'Parcial2', 'Parcial3']
# ['2026001', 'Ana López', 'Sistemas', '90', '95', '88']
# ['2026002', 'Carlos Pérez', 'Sistemas', '75', '80', '78']
# ['2026003', 'María García', 'Sistemas', '100', '95', '98']
# ['2026004', 'Juan Hernández', 'Sistemas', '60', '70', '65']
# ['2026005', 'Sofía Ramírez', 'Sistemas', '85', '90', '87']
# ['2026006', 'Luis Torres', 'Sistemas', '70', '75', '80']
# ['2026007', 'Valeria Cruz', 'Sistemas', '95', '92', '96']
# ['2026008', 'Diego Flores', 'Sistemas', '88', '84', '90']
# ['2026009', 'Fernanda Ruiz', 'Sistemas', '78', '82', '80']
# ['2026010', 'Miguel Sánchez', 'Sistemas', '92', '89', '94']
# ['2026011', 'Karen Mendoza', 'Sistemas', '65', '70', '68']
# ['2026012', 'José Morales', 'Sistemas', '80', '85', '83']
# ['2026013', 'Andrea Vargas', 'Sistemas', '98', '97', '99']
# ['2026014', 'Ricardo Castro', 'Sistemas', '55', '60', '58']
# ['2026015', 'Paola Jiménez', 'Sistemas', '87', '90', '85']
# ...

# %%
import csv
archivo_csv = "calificaciones.csv"
suma_promedios_grupo = 0
total_alumnos = 0
aprobados = 0
reprobados = 0
mejor_alumno = ""
peor_alumno = ""
mejor_promedio = -1
peor_promedio = 101
lista_alumnos = []
try:
    with open(archivo_csv, "r", encoding="utf-8") as archivo:
        lector = csv.reader(archivo)
        next(lector)

        for fila in lector:
            nombre = fila[1]
            p1, p2, p3 = int(fila[3]), int(fila[4]), int(fila[5])

            promedio_alumno = (p1 + p2 + p3) / 3

            suma_promedios_grupo += promedio_alumno
            total_alumnos += 1

            if promedio_alumno >= 70:
                aprobados += 1
            else:
                reprobados += 1

            if promedio_alumno > mejor_promedio:
                mejor_promedio = promedio_alumno
                mejor_alumno = nombre

            if promedio_alumno < peor_promedio:
                peor_promedio = promedio_alumno
                peor_alumno = nombre

            lista_alumnos.append((nombre, promedio_alumno))

    if total_alumnos > 0:
        promedio_general = suma_promedios_grupo / total_alumnos
        print(f" {total_alumnos}  el promedio general del grupo quedó en {promedio_general:.2f}.")
        print(f" {aprobados} alumnos lograron aprobar la materia, mientras que {reprobados} fueron reprobados.")
        print(f" el promedio más alto lo obtuvo {mejor_alumno} con un total de {mejor_promedio:.2f}, que el más bajo fue el de {peor_alumno} con {peor_promedio:.2f}.\n")
        lista_alumnos.sort(key=lambda x: x[1], reverse=True)

        print("Lista ordenada de alumnos de mayor a menor promedio:")
        for puesto, (nombre, promedio) in enumerate(lista_alumnos, start=1):
            print(f"Posición {puesto}: {nombre} con un promedio de {promedio:.2f}")

    else:
        print("No se encontraron registros de alumnos para procesar en el archivo.")

except FileNotFoundError:
    print(f"No pude encontrar el archivo '{archivo_csv}'. Revisa que esté en la misma carpeta.")
# Out:
#  20  el promedio general del grupo quedó en 82.70.
#  17 alumnos lograron aprobar la materia, mientras que 3 fueron reprobados.
#  el promedio más alto lo obtuvo Andrea Vargas con un total de 98.00, que el más bajo fue el de Ricardo Castro con 57.67.
#
# Lista ordenada de alumnos de mayor a menor promedio:
# Posición 1: Andrea Vargas con un promedio de 98.00
# Posición 2: María García con un promedio de 97.67
# Posición 3: Brenda Ortiz con un promedio de 95.00
# Posición 4: Valeria Cruz con un promedio de 94.33
# Posición 5: Miguel Sánchez con un promedio de 91.67
# Posición 6: Ana López con un promedio de 91.00
# Posición 7: Camila Vega con un promedio de 90.00
# Posición 8: Sofía Ramírez con un promedio de 87.33
# Posición 9: Diego Flores con un promedio de 87.33
# Posición 10: Paola Jiménez con un promedio de 87.33
# Posición 11: Emilio Rojas con un promedio de 84.00
# Posición 12: José Morales con un promedio de 82.67
# Posición 13: Fernanda Ruiz con un promedio de 80.00
# ...
